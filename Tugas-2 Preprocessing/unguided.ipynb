# %% [markdown]
# 1. Load data (movie classification)

# %%
import pandas as pd
import numpy as np

# %%
# Load the CSV file into a pandas DataFrame
file_path = 'Movie_classification.csv'
df = pd.read_csv(file_path)
df
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0              20.1264               59.62               0.462  36524.125
# 1              20.5462               69.14               0.531  35668.655
# 2              20.5458               69.14               0.531  39912.675
# 3              20.6474               59.36               0.542  38873.890
# 4              21.3810               59.36               0.542  39701.585
# ..                 ...                 ...                 ...        ...
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
df.head()
# Out:
#    Marketing expense  Production expense  Multiplex coverage     Budget  \
# 0            20.1264               59.62               0.462  36524.125
# 1            20.5462               69.14               0.531  35668.655
# 2            20.5458               69.14               0.531  39912.675
# 3            20.6474               59.36               0.542  38873.890
# 4            21.3810               59.36               0.542  39701.585
#
#    Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 0         138.7               7.825                8.095            7.910
# 1         152.4               7.505                7.650            7.440
# 2         134.6               7.485                7.570            7.495
# 3         119.3               6.895                7.035            6.920
# 4         127.7               6.920                7.070            6.815
#
#    Producer_rating  Critic_rating  Trailer_views 3D_available  Time_taken  \
# ...

# %%
df.tail()
# Out:
#      Marketing expense  Production expense  Multiplex coverage     Budget  \
# 501            21.2526               78.86               0.427  36624.115
# 502            20.9054               78.86               0.427  33996.600
# 503            21.2152               78.86               0.427  38751.680
# 504            22.1918               78.86               0.427  37740.670
# 505            20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# 501         142.6                8.68                8.775            8.620
# 502         150.2                8.78                8.945            8.770
# 503         164.5                8.83                8.970            8.855
# 504         162.8                8.73                8.845            8.800
# 505         154.3                8.64                8.880            8.680
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Marketing expense    506 non-null    float64
#  1   Production expense   506 non-null    float64
#  2   Multiplex coverage   506 non-null    float64
#  3   Budget               506 non-null    float64
#  4   Movie_length         506 non-null    float64
#  5   Lead_ Actor_Rating   506 non-null    float64
#  6   Lead_Actress_rating  506 non-null    float64
#  7   Director_rating      506 non-null    float64
#  8   Producer_rating      506 non-null    float64
#  9   Critic_rating        506 non-null    float64
#  10  Trailer_views        506 non-null    int64
#  11  3D_available         506 non-null    object
#  12  Time_taken           494 non-null    float64
#  13  Twitter_hastags      506 non-null    float64
#  14  Genre                506 non-null    object
# ...

# %% [markdown]
# 2. Cek nilai duplikat

# %%
# Memeriksa nilai duplikat  
int(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# 3. Menemukan null values buat presentase

# %%
# Analisis nilai hilang dalam DataFrame
null_analysis = df.isnull().sum().to_frame('Null Values')
null_analysis['Total Values'] = df.count()
null_analysis['Percentage Null (%)'] = (null_analysis['Null Values'] / len(df)) * 100

# Menampilkan kolom dengan nilai hilang
print(null_analysis[null_analysis['Null Values'] > 0])
# Out:
#             Null Values  Total Values  Percentage Null (%)
# Time_taken           12           494             2.371542

# %% [markdown]
# 4. Drop missing value berdasarkan baris, kolom, imputasi dengan mean, modus, median

# %%
#mencari berapa banyak nilai yang hilang
imputate = df.select_dtypes(include=[np.number])
imputate.isna().sum()
# Out:
# Marketing expense       0
# Production expense      0
# Multiplex coverage      0
# Budget                  0
# Movie_length            0
# Lead_ Actor_Rating      0
# Lead_Actress_rating     0
# Director_rating         0
# Producer_rating         0
# Critic_rating           0
# Trailer_views           0
# Time_taken             12
# Twitter_hastags         0
# Avg_age_actors          0
# Num_multiplex           0
# Collection              0
# Start_Tech_Oscar        0
# dtype: int64

# %%
# Drop rows with missing values
data_drop_row = df.dropna()

# %%
# Drop columns with missing values
data_drop_columns = df.dropna(axis=1)

# %%
# Impute with mean
data_impute_mean = df.copy()
data_impute_mean['Time_taken'] = data_impute_mean['Time_taken'].fillna(data_impute_mean['Time_taken'].mean())

data_impute_mean.isna().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Start_Tech_Oscar       0
# dtype: int64

# %%
# Impute with median
data_impute_median = df.copy()
data_impute_median['Time_taken'] = data_impute_median['Time_taken'].fillna(data_impute_median['Time_taken'].median())

data_impute_median.isna().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Start_Tech_Oscar       0
# dtype: int64

# %%
# Impute with modus
data_impute_modus = df.copy()
data_impute_modus['Time_taken'] = data_impute_modus['Time_taken'].fillna(data_impute_modus['Time_taken'].mode()[0])

data_impute_modus.isnull().sum()
# Out:
# Marketing expense      0
# Production expense     0
# Multiplex coverage     0
# Budget                 0
# Movie_length           0
# Lead_ Actor_Rating     0
# Lead_Actress_rating    0
# Director_rating        0
# Producer_rating        0
# Critic_rating          0
# Trailer_views          0
# 3D_available           0
# Time_taken             0
# Twitter_hastags        0
# Genre                  0
# Avg_age_actors         0
# Num_multiplex          0
# Collection             0
# Start_Tech_Oscar       0
# dtype: int64

# %% [markdown]
# 5. Export data ke csv dan excel

# %%
#eksport data ke csv dan excel

df.to_csv('Movie_classification_clean.csv', index=False)
df.to_excel('Movie_classification_clean.xlsx', index = False)
